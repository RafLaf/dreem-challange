# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import pandas as pd

# %%
X=np.load('R43.npy',allow_pickle=True)

# %%
pca=PCA()

# %%
pca.fit(X)
print(pca.explained_variance_ratio_[:10])
# Out:
# [0.11737243 0.07639866 0.06062301 0.05127792 0.04745815 0.03997212
#  0.03103863 0.02912193 0.02191224 0.01936015]

# %%
selec
# Out:
# array([  49,  452,  453,  281,  141,  496, 1776, 1396, 1617,  203,  494,
#          63,  889,  900,  871])

# %%
filename='y_train.csv'

ytrain=np.array(pd.read_csv(filename))
for i in range(5):
    print('occurence sleep stage',i,np.count_nonzero(ytrain[:,1]== i))
y=ytrain[:,1]
# Out:
# occurence sleep stage 0 3511
# occurence sleep stage 1 1671
# occurence sleep stage 2 9449
# occurence sleep stage 3 5224
# occurence sleep stage 4 4833

# %%
X2=pca.transform(X)

# %%
np.save('RCpca.npy',X2[:,:4])

# %%
X2[np.where(y==2),0]
# Out:
# array([[  4.37187788,   9.28792504,  19.46742644, ...,  -0.64718606,
#           2.66872585, -15.93920689]])

# %%
for i in range(5):
    plt.plot(X2[np.where(y==i),0],X2[np.where(y==i),1],'.',markersize=0.5)
